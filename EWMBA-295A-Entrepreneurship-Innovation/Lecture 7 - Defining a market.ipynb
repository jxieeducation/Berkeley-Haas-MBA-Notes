# %% [markdown]
# ## Quotes
# * "PokemonGo were off their TAM by 15x, but in the good way"
# * Look at s-1s, they are a snapshot of a company in time that tells you a lot about the industry
# * "One of my worst investment decisions was in 2008 w/ Zynga's seed round." (did not invet because Professor Kurt Beyer did not understand the virtual good revenue model)
# * "Do you know the sad cow in farmville? Invented by a Haas alum, who was the head of product, and revolutionized AB Testing in social gaming"
# * "Zynga isn't a gaming company, they revolutioned software design" (referring to iteration cycles)

# %% [markdown]
# * have a plan for who to hire and when to hire, to avoid last minute winging hiring decisions
#     * avoid hiring friends (people who mgith not be a good fit skillwise)

# %% [markdown]
# * strategy canvas analysis
#     * list out things that matter, and then compare company and competitors on these terms to figure out blue ocean

# %%
from IPython.display import Image
Image("pics/strategy_canvas.png")

# %% [markdown]
# * identifying blue oceans
#     * look across alternative industries
#     * look across groups within industry
#     * look across the chain of buyers
#     * look across complimentary product / services, product life cycles
#     * look across functional / emotional buyer appeal
#     * look across time
#
# * TAM
# * SAM - serviceable addressable market - based on current biz model
# * SOM - serviceable obtainable market - based on internal resources / practical limits of biz model

# %% [markdown]
# * biz model simulation
#     * rev model
#     * cost model
#     * investment model
#     * critical success factors - cash flow
